# %%
import os

import numpy as np
import pandas as pd
from numpy.lib.stride_tricks import sliding_window_view

import torch

# %%
PATH = "../../data/preprocessed"

# %%
dynamic_data = np.load(f"{PATH}/dynamic.npy")

# %%
static_data = np.load(f"{PATH}/static.npy")

# %%
dynamic_data.shape
# Out:
# (10027, 5, 14049)

# %%
X, y = sliding_windows(dynamic_data, 12, 12)
print(X.shape)
print(y.shape)
# Out:
# (702, 10027, 5, 12)
# (702, 10027, 5, 12)

# %%
X.isnull
